# %%
def fib(n):
    if n==1 or n==2:
        return 1
    return fib(n-1) + fib(n-2)

# %%
fib(40)
# Out:
# 102334155

# %%
import time
start = time.clock()
print fib(40)
print (time.clock() - start, "seconds")

import time
start = time.clock()
print fib(41)
print (time.clock() - start, "seconds")

import time
start = time.clock()
print fib(39)
print (time.clock() - start, "seconds")
# Out:
# 102334155
# (20.896238762034336, 'seconds')
# 165580141
# (33.83688998720115, 'seconds')
# 63245986
# (12.972392550584388, 'seconds')

# %%
import math
import numpy
import cmath

def modul_plus_arg(x, y):
    mod = abs(complex(x, y))
    arg = cmath.phase(complex(x, y))
    return mod, arg
        

print (type(modul_plus_arg(3,4)))
print (modul_plus_arg(3,4))
# Out:
# <type 'tuple'>
# (5.0, 0.9272952180016122)

# %%
import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=0)

# %%
import time

class Complex(object):
    def __init__(self, real, imag=None):
        self.real = real
        self.imag = 0

    def __str__(self):
        return "({0}+{1}j)".format(self.real, self.imag)

start = time.time()
primeNumbers = []
output = ""

for i in xrange(2, 100000):
    divisible = False
    inum = Complex(i)

    for number in primeNumbers:
        if inum.real % number.real == 0:
            divisible = True
            break

    if divisible == False:
        primeNumbers.append(inum)
        output += str(inum)


print 'time: %f' % (time.time() - start)
print len(primeNumbers), len(output)
# Out:
# time: 6.608000
# 9592 94494

# %%
import collections
import functools
    
def memoize(obj):
    cache = obj.cache = {}
    
    @functools.wraps(obj)
    def memoizer(*args, **kwargs):
        if args not in cache:
            cache[args] = obj(*args, **kwargs)
        return cache[args]
    return memoizer

@memoized
def fibonacci(n):
    if n in (0, 1):
        return n
    return fibonacci(n-1) + fibonacci(n-2)
# Out:
# 55

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
params = {'color':'red',}
plt.plot(list((0,1,2)),list((0,1,2)), **params)
plt.plot(list((0,1,2)),list((0,1,2)), color='red')

# %%
def benchmark(func):
    import time
    def wrapper(*args, **kwargs):
        t = time.clock()
        res = func(*args, **kwargs)
        print (func.__name__, time.clock() - t)
        return res
    return wrapper

# %%
import collections
import functools
    

def benchmark(func):
    import time
    def wrapper(*args, **kwargs):
        t = time.clock()
        res = func(*args, **kwargs)
        print (func.__name__, time.clock() - t)
        return res
    return wrapper

def memoize(obj):
    cache = obj.cache = {}
    
    @functools.wraps(obj)
    def memoizer(*args, **kwargs):
        if args not in cache:
            cache[args] = obj(*args, **kwargs)
        return cache[args]
    return memoizer

@memoize
def fibonacci_f3(f3):
    return fibonacci(f3)

@memoize
@benchmark
def fibonacci_f(f):
    return fibonacci(f)

@benchmark
@memoize
def fibonacci_f1(f1):
    return fibonacci(f1)

@benchmark
def fibonacci_f2(f2):
    return fibonacci(f2)

start_time = time.clock()
print (fibonacci_f3(41))
print (time.clock() - start_time, "seconds")
print (fibonacci_f(41))
print (fibonacci_f1(41))
print (fibonacci_f2(41))
# Out:
# 165580141
# (0.00045311082249099854, 'seconds')
# ('fibonacci_f', 1.4444807675317861e-05)
# 165580141
# ('fibonacci_f1', 2.4708224373171106e-05)
# 165580141
# ('fibonacci_f2', 1.7485819626017474e-05)
# 165580141

# %%
def get_x(self):
    return self.__x

def set_x(self, x):
    self.__x = x

# %%
url = "https://lenta.ru/articles/2017/05/18/alko_online_russia/"

import requests
from bs4 import BeautifulSoup

text = requests.get(url).text
bs4_object = BeautifulSoup(text, "lxml")

print (bs4_object.find(itemprop="articleBody").text)
# Out:
# Российские власти всерьез задумались о том, чтобы разрешить продажу алкоголя в интернете, предложив начать с вина и пива. Против этой инициативы выступает Роспотребнадзор — там опасаются, что торговля спиртным в сети сведет на нет усилия в борьбе с пьянством. В то же время в онлайн-«витринах» уже сегодня без проблем можно заказать с доставкой на дом любой алкоголь, включая водку, коньяк, виски. «Лента.ру» разбиралась в ситуации.
#
# ...

# %%
# !pip install bs4
# Out:
# ...
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import numpy as np
massiv = np.ndarray(shape=(3,4,2), dtype=int, order='F')


print (massiv[0,1])
print (massiv)
print (massiv[2,3,1])
# Out:
# [825242669   5010293]
# [[[ -99859352          0]
#   [ 825242669    5010293]
#   [   6029417          0]
#   [ 761608499  774988386]]
#
#  [[ 812003430  959655985]
#   [         0         50]
#   [1952543859  942486321]
#   [         0  892234853]]
#
#  [[         0 1852990827]
#   [ 962736951 1664694325]
#   [       338          0]
#   [ 878849331        115]]]
# 115

# %%
import time
import numpy as np

arr = np.ndarray(shape=(5000), dtype=int, order='F')

start_time = time.clock()

for x in range(0, 10000):
    np.flipud(arr)
print (time.clock() - start_time, "seconds")

list = [x for x in range(5000)]

start_time = time.clock()

for x in range(0, 10000):
    list.reverse()
print (time.clock() - start_time, "seconds")
# Out:
# 0.010926492680756184 seconds
# 0.029370415739201405 seconds

# %%
def timelinspace(*args, **kwargs):
    start_time = time.clock()
    ret = np.linspace(*args, **kwargs)
    print (time.clock() - start_time, "seconds")
    return ret

def listlinspace(*args, **kwargs):
    start_time = time.clock()
    num = kwargs.get('num', 50)
    endpoint = kwargs.get('endpoint', True)
    retstep = kwargs.get('retstep', False)
    start = args[0]
    end = args[1]
    if (len(args)>2):
        num = args[2]
    ret = [(end-start)/(num-1*endpoint)*i+start for i in range(num)]
    print (time.clock() - start_time, "seconds")
    if(retstep):
        return (ret, (end-start)/(num-1*endpoint))
    return ret


print(listlinspace(-100.0, -50.0, 7))

timelinspace(1.0, 500.0, 100000)
listlinspace(1.0, 500.0, 100000)
# Out:
# 9.386654653553705e-06 seconds
# [-100.0, -91.66666666666667, -83.33333333333333, -75.0, -66.66666666666666, -58.33333333333333, -50.0]
# 0.002655569934233881 seconds
# 0.02646524612447365 seconds
# [1.0,
#  1.0049900499004991,
#  1.009980099800998,
#  1.014970149701497,
#  1.019960199601996,
#  1.0249502495024951,
#  1.029940299402994,
#  1.034930349303493,
#  1.039920399203992,
#  1.0449104491044912,
#  1.04990049900499,
#  1.054890548905489,
#  1.059880598805988,
#  1.0648706487064872,
#  1.069860698606986,
#  1.074850748507485,
#  1.079840798407984,
#  1.0848308483084832,
#  1.089820898208982,
#  1.094810948109481,
#  1.09980099800998,
#  1.1047910479104792,
#  1.1097810978109781,
#  1.114771147711477,
#  1.1197611976119761,
#  1.1247512475124752,
#  1.1297412974129741,
#  1.134731347313473,
#  1.1397213972139721,
#  1.1447114471144713,
#  1.1497014970149702,
#  1.154691546915469,
#  1.1596815968159682,
#  1.1646716467164673,
#  1.1696616966169662,
#  1.174651746517465,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.plot(X, C, color="blue", linewidth=2.5, linestyle="-", label="cosine")
plt.plot(X, S, color="red",  linewidth=2.5, linestyle="-", label="sine")

plt.legend(loc='upper left')

plt.savefig('Grafici.png') 
plt.show()

# %%
import math
x = np.linspace(-2, 2)

plt.figure(1)
plt.subplot(2,2,1)
plt.title('square')
plt.plot(x, [y**2 for y in  np.linspace(-2, 2)])

plt.subplot(2,2,2)
plt.title('cube')
plt.plot(x, [y**3 for y in  np.linspace(-2, 2)])

plt.subplot(2,2,3)
plt.title('log')
plt.plot(np.linspace(0.00001, 2), [math.log(y) for y in  np.linspace(0.00001, 2)])

plt.subplot(2,2,4)
plt.title('exp')
plt.plot(x, [math.exp(y) for y in  np.linspace(-2, 2)])
plt.show()

# %%
def f(x,y):
    return 3*x*y + x - 2*y

x = np.arange(0.0,5.0,0.01)
y = np.arange(0.0,5.0,0.01)

X,Y = np.meshgrid(x, y)
Z =f(X,Y)
plt.pcolormesh(X,Y,Z)
plt.imshow(Z, extent=[2,5,5,0])
plt.colorbar()
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import random


fig = plt.figure()
ax = fig.add_subplot(1,1,1, projection='3d')

x = np.arange(0.0,5.0,0.01)
y = np.arange(0.0,5.0,0.01)

X,Y = np.meshgrid(x, y)

zs = np.array([f(x,y) for x,y in zip(np.ravel(X), np.ravel(Y))])
Z = zs.reshape(X.shape)

ax.plot_surface(X, Y, Z)

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')

plt.show()

# %%
from scipy import optimize

x = np.arange(-2.5, 2.5, 0.01)
y = np.array(x**3+2*x**2+3*x+2+np.random.randn(len(x))/10)

def f(kb):
    sum = 0;
    numLoops = len(x)
    for i in range(0,numLoops-1):
        sum += (y[i]-kb[0]*x[i]**3-kb[1]*x[i]**2-kb[2]*x[i]-kb[3])**2
    return sum

print (f([1, 2, 3, 2]))
print (f([0.999,  1.999,  3.001,  2]))

x_min = optimize.minimize(f, [0, 0, 0, 0])
print (x_min.x)

def foo(x):
    kb = x_min.x
    return kb[0]*x**3-kb[1]*x**2-kb[2]*x-kb[3]

foo_min = optimize.fmin(foo, 0)
foo_max = optimize.fmin(lambda x: -foo(x), 0)

plt.plot(x, y, 'y')
y_counted = foo(x)
plt.plot(x, y_counted, 'b')
plt.plot(np.array([foo_min]), np.array([foo(foo_min)]),'og')
plt.plot(np.array([foo_max]), np.array([foo(foo_max)]), 'or')
plt.show()
# Out:
# 4.96815364281
# 4.9893744397
# [ 1.00182008  1.99945288  2.99405733  1.9983628 ]
# Optimization terminated successfully.
#          Current function value: -8.038131
#          Iterations: 27
#          Function evaluations: 54
# Optimization terminated successfully.
#          Current function value: 1.122242
#          Iterations: 23
#          Function evaluations: 46
